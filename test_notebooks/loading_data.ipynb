# %%
import numpy as np
from bokeh.plotting import figure, output_notebook, show, gridplot
from bokeh.models import axes

# %%
trajectory = np.genfromtxt('../sample_data/Sample_Trajectory_Data1.csv',
            delimiter =",")

# %%
trajectory=np.delete(trajectory, 0,0)

# %%
time = trajectory[:,0]
PLGA_4A_UP_R1_P25 = trajectory[:,1:4]
PLGA_4A_P80_R1_P22 = trajectory[:,4:7]
PLGA_15k_UP_R3_P5 = trajectory[:,7:10]
PLGA_15k_P80_R3_P36 = trajectory[:,10:13]
PLGA_4A_F68_R3_P15 = trajectory[:,13:16]
PLGA_15k_F68_R3_P10 = trajectory[:,16:19]
PLGA4A_5CHA_R3_P124 = trajectory[:,19:22]
PLGA_15k_5CHA_R3_P50 = trajectory[:,22:25]
PLGA_15k_2CHA_R2_P44 = trajectory[:,25:28]
PLGA15k_05CHA_R3_P22 = trajectory[:,28:31]
PEG_PLGA15k_P80_R3_P127 = trajectory[:,31:34]
PEG_PLGA4A_F68_R3_P111 = trajectory[:,34:37]
PEG_PLGA4A_P80_R1_P84 = trajectory[:,37:40]
PEG_PLGA4A_UP_R1_P53 = trajectory[:,40:43]
PEG_PLGA15k_2CHA_R2_P26 = trajectory[:,43:46]
PEG_PLGA15k_5CHA_R2_P52 = trajectory[:,46:49]
PEG_PLGA15k_UP_R3_P61 = trajectory[:,49:52]
PEG_PLGA58k_5CHA_R2_P15 = trajectory[:,52:55]
PEG_PLGA15k_F68_R2_P81 = trajectory[:,55:58]
PLGA_15k_2CHA_R2_P37 = trajectory[:,58:61]
PLGA_15k_PEG_2CHA_R2_P81 = trajectory[:,61:64]
PLGA_15k_05CHA_R1_P45 = trajectory[:,64:67]
PLGA_15k_PEG_05CHA_R3_P61 = trajectory[:,67:70]

# %%
#output to notebook
output_notebook()

#create a plot of trajectory data
x = PLGA_4A_UP_R1_P25[:,1]
y = PLGA_4A_UP_R1_P25[:,2]
p = figure(title='PLGA_4A_UP_R1_P25', x_axis_label='x', y_axis_label='y')
p.line(x, y, line_width=2)

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c478e77-2db6-4be2-9c1f-4ee58c37b1a0">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="6af22d1b-0554-44e5-8b08-014fcf4040fe"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6af22d1b-0554-44e5-8b08-014fcf4040fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6af22d1b-0554-44e5-8b08-014fcf4040fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"643d94bb-f4a8-454d-8e70-ef647fce5c5b":{"roots":{"references":[{"attributes":{},"id":"d6b0d4ba-802b-4cff-b1e4-1864e1fd49b6","type":"ToolEvents"},{"attributes":{"plot":{"id":"e5422c85-2231-49aa-b413-ea05315a4d1c","subtype":"Figure","type":"Plot"}},"id":"df20db17-5b38-477e-8f88-43f6fc539f47","type":"PreviewSaveTool"},{"attributes":{},"id":"ef3c3466-8639-4065-8ade-eefa611156e4","type":"BasicTicker"},{"attributes":{"plot":{"id":"e5422c85-2231-49aa-b413-ea05315a4d1c","subtype":"Figure","type":"Plot"}},"id":"8634f6a9-1f33-45c7-b1cd-82ce2e69992d","type":"ResizeTool"},{"attributes":{"plot":{"id":"e5422c85-2231-49aa-b413-ea05315a4d1c","subtype":"Figure","type":"Plot"}},"id":"a957c044-d321-4b16-9e95-ae009900b9c2","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a4fa005d-c198-4905-984e-07afc84d4091","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"74205981-a8bc-4766-b230-bc570be2ba1b","type":"DataRange1d"},{"attributes":{"below":[{"id":"1cc21bf0-c519-4f49-8b47-b0e3bd8e3236","type":"LinearAxis"}],"left":[{"id":"ad45bb64-67ca-4994-93d1-5bafd984b549","type":"LinearAxis"}],"renderers":[{"id":"1cc21bf0-c519-4f49-8b47-b0e3bd8e3236","type":"LinearAxis"},{"id":"baed5744-963e-4b9d-b333-5931f982ea6a","type":"Grid"},{"id":"ad45bb64-67ca-4994-93d1-5bafd984b549","type":"LinearAxis"},{"id":"29d6cbd6-435b-4b9e-8cb0-1c220c2ff5da","type":"Grid"},{"id":"7cd1c0cc-66cb-4e56-b141-0df03dd7cdef","type":"BoxAnnotation"}],"title":"PLGA_4A_UP_R1_P25","tool_events":{"id":"a4f9a93d-ca67-4784-90c3-539e99f00bc9","type":"ToolEvents"},"tools":[{"id":"f4b3ecc2-8305-4df1-8a8a-2e79c05b9cc7","type":"PanTool"},{"id":"48771733-b949-4e54-b1c6-c7d55e7ffa64","type":"WheelZoomTool"},{"id":"fe308f8d-2679-4b0d-9853-890ef11b604a","type":"BoxZoomTool"},{"id":"11d973ff-420f-4c10-9ebb-20b09349fcd4","type":"PreviewSaveTool"},{"id":"8e2c6c89-0b6c-4781-b006-c227e89e9cdf","type":"ResizeTool"},{"id":"498c7a58-ea10-43e8-8425-bfa91fc06321","type":"ResetTool"},{"id":"2f40c6de-becf-43af-b9de-c36542e9e6c2","type":"HelpTool"}],"x_range":{"id":"05c9b2e1-629b-4a56-a399-55eecdf5cb9a","type":"DataRange1d"},"y_range":{"id":"74205981-a8bc-4766-b230-bc570be2ba1b","type":"DataRange1d"}},"id":"70c8aec3-426b-473e-9a10-c638a865e249","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"6259f986-b29d-45d9-933e-28a283b0462a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"70c8aec3-426b-473e-9a10-c638a865e249","subtype":"Figure","type":"Plot"},"ticker":{"id":"92da15fc-aee2-48ba-b25c-cc899671b252","type":"BasicTicker"}},"id":"29d6cbd6-435b-4b9e-8cb0-1c220c2ff5da","type":"Grid"},{"attributes":{},"id":"254b455c-4056-4b4a-b853-a69e3897361a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"c2c529ae-68ec-4b1c-81c0-f41d5cf732b6","type":"LinearAxis"}],"left":[{"id":"61db07ea-3123-4d00-8514-df320f8d1d8b","type":"LinearAxis"}],"renderers":[{"id":"c2c529ae-68ec-4b1c-81c0-f41d5cf732b6","type":"LinearAxis"},{"id":"e43f70fd-194f-497b-855f-e087b9e94d25","type":"Grid"},{"id":"61db07ea-3123-4d00-8514-df320f8d1d8b","type":"LinearAxis"},{"id":"9c4f3b2d-da91-4275-8053-effb7feb3e11","type":"Grid"},{"id":"a4fa005d-c198-4905-984e-07afc84d4091","type":"BoxAnnotation"},{"id":"8d74569f-add9-42fa-8c3d-f8e5e9e33cc7","type":"GlyphRenderer"}],"title":"PLGA_4A_UP_R1_P25","tool_events":{"id":"d6b0d4ba-802b-4cff-b1e4-1864e1fd49b6","type":"ToolEvents"},"tools":[{"id":"5ac722f5-a605-46af-b47d-82b02fa5262c","type":"PanTool"},{"id":"d3d3a5bf-ea85-41c2-b997-a529ed216ce4","type":"WheelZoomTool"},{"id":"b0e66f0a-9274-4db3-9c5f-24a3f5f512b4","type":"BoxZoomTool"},{"id":"df20db17-5b38-477e-8f88-43f6fc539f47","type":"PreviewSaveTool"},{"id":"8634f6a9-1f33-45c7-b1cd-82ce2e69992d","type":"Re ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[48]</strong>&gt;</code></p>

# %%
def plot_trajectory(xydata, charttitle):
    
    output_notebook()  
    x = xydata[:,1]
    y = xydata[:,2]
    p = figure(title=charttitle, title_text_font_size='8pt', 
               axis_label_text_font_size='5pt',
               width = 300, height = 300, x_axis_label='x', y_axis_label='y')
    p.line(x, y, line_width=2)
    show(p)

# %%
plot_trajectory(PEG_PLGA15k_2CHA_R2_P26, 'PEG_PLGA15k_2CHA_R2_P26')
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="90e6cb3c-b113-4dd4-a1b6-94e6cb87d3b7">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-b598d5935936> in <module>()
# ----> 1 plot_trajectory(PEG_PLGA15k_2CHA_R2_P26, 'PEG_PLGA15k_2CHA_R2_P26')
#
# <ipython-input-78-04946435a5e9> in plot_trajectory(xydata, charttitle)
#       6     p = figure(title=charttitle, title_text_font_size='8pt',
#       7                axis_label_text_font_size='5pt',
# ----> 8                width = 300, height = 300, x_axis_label='x', y_axis_label='y')
#       9     p.line(x, y, line_width=2)
#      10     show(p)
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\plotting\figure.py in figure(**kwargs)
#     619         kwargs['plot_width'] = kwargs.pop('width')
#     620
# --> 621     fig = Figure(**kwargs)
#     622     curdoc()._current_plot = fig # TODO (havocp) store this on state, not doc?
#     623     if curstate().autoadd:
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\plotting\figure.py in __init__(self, *arg, **kw)
#      42         y_axis_label = kw.pop("y_axis_label", "")
#      43
# ---> 44         super(Figure, self).__init__(*arg, **kw)
#      45
#      46         self.x_range = _get_range(x_range)
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\models\plots.py in __init__(self, **kwargs)
#      76             raise ValueError("Conflicting properties set on plot: background_fill, background_fill_color.")
#      77
# ---> 78         super(Plot, self).__init__(**kwargs)
#      79
#      80     def select(self, *args, **kwargs):
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#      81         self._id = kwargs.pop("id", make_id())
#      82         self._document = None
# ---> 83         super(Model, self).__init__(**kwargs)
#      84         default_theme.apply_to_model(self)
#      85
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\core\properties.py in __init__(self, **properties)
#     699
#     700         for name, value in properties.items():
# --> 701             setattr(self, name, value)
#     702
#     703     def __setattr__(self, name, value):
#
# C:\Users\koolk\Miniconda3\lib\site-packages\bokeh\core\properties.py in __setattr__(self, name, value)
#     720
#     721             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 722                 (name, self.__class__.__name__, text, nice_join(matches)))
#     723
#     724     def set_from_json(self, name, json, models=None):
#
# AttributeError: unexpected attribute 'axis_label_text_font_size' to Figure, similar attributes are title_text_font_size, title_text_font_style or title_text_font

# %%
def sidebyside(xydata1, xydata2, charttitle1, charttitle2):
    
    output_notebook()  
    x1 = xydata1[:,1]
    y1 = xydata1[:,2]
    x2 = xydata2[:,1]
    y2 = xydata2[:,2]
    
    s1 = figure(title=charttitle1, width = 300, height = 300, x_axis_label='x', y_axis_label='y')
    s1.line(x1, y1, color='navy', line_width=2)
    
    s2 = figure(title=charttitle2, width = 300, height = 300, x_range=s1.x_range, y_range=s1.y_range, x_axis_label='x', y_axis_label='y')
    s2.line(x2, y2, color='firebrick', line_width=2)    
    
    p = gridplot([[s1, s2]])
    
    show(p)

# %%
sidebyside(PEG_PLGA15k_2CHA_R2_P26, PLGA_15k_2CHA_R2_P37, 'PEG', 'No PEG')
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ac9038bb-df81-480b-9adb-8557bce3c71c">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="4d718042-57f4-4f0b-9fa7-58333a076f15"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d718042-57f4-4f0b-9fa7-58333a076f15");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d718042-57f4-4f0b-9fa7-58333a076f15' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b688a15b-128d-4414-8a7a-37f4ce51ea3e":{"roots":{"references":[{"attributes":{},"id":"072be169-274f-4cff-9862-16ab81e13b41","type":"BasicTicker"},{"attributes":{},"id":"35b9f6b1-e4c4-4e0a-a73c-a02d9312feb0","type":"BasicTicker"},{"attributes":{"overlay":{"id":"643800fe-5dfc-4e5e-a302-be63f4e9c6f5","type":"BoxAnnotation"},"plot":{"id":"ff884326-abc8-4735-a0fa-e5b028d34a2f","subtype":"Figure","type":"Plot"}},"id":"e7f79390-1514-4e71-ad92-477a82740bd5","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"dccf8db9-37e2-4569-b6ef-da8a3ca971bd","type":"ColumnDataSource"},"glyph":{"id":"5bbcf9e7-310b-4832-a51d-a49d3aa3e63a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9ba5c53f-14f0-480e-a55c-d66a21564e17","type":"Line"},"selection_glyph":null},"id":"d4c81605-a744-484a-a4e0-8adf48e41126","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ff884326-abc8-4735-a0fa-e5b028d34a2f","subtype":"Figure","type":"Plot"}},"id":"ed697812-9649-4741-8b74-2754ad3547e5","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"3f56b31d-552f-4d18-b149-1898c3f4ad4e","subtype":"Figure","type":"Plot"}},"id":"d5e10c11-711e-471d-aff6-4fc07f66ca98","type":"PreviewSaveTool"},{"attributes":{},"id":"6f5ed664-1bbc-4ca4-a002-b90e94671d46","type":"BasicTicker"},{"attributes":{},"id":"5abbb410-0622-4fa6-a5a1-1153a7d6b18a","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7685706f-812d-4dc8-84fa-489586605e15","type":"Line"},{"attributes":{"plot":{"id":"fbbd7ca5-3f2e-4e53-ac5c-5cfbfdc66f10","subtype":"Figure","type":"Plot"}},"id":"a4429e70-2141-4db2-9169-0393b1770062","type":"HelpTool"},{"attributes":{},"id":"30d01315-2016-49db-bea9-d69a9e313bc0","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fa680de-8a13-44ce-9d4c-3aedd1b77bcf","type":"Line"},{"attributes":{"overlay":{"id":"8f2ed6c3-4a2d-4157-9b4b-9819cbf072ab","type":"BoxAnnotation"},"plot":{"id":"42f2bb90-8ef7-4281-9315-2d9c740ba5c3","subtype":"Figure","type":"Plot"}},"id":"5396bed4-ddb4-4022-be5a-acecf740ee57","type":"BoxZoomTool"},{"attributes":{},"id":"1c1ca632-ba3a-49d9-9ceb-26d3cb97b619","type":"ToolEvents"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"04022468-627b-45e1-a4d0-52bb81395b7e","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7f5c2d1c-7968-48ca-9733-897176408ac0","type":"BoxAnnotation"},{"attributes":{},"id":"1fcbf84d-73ab-4c47-8f51-b9910624ab80","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca385ffd-1b73-4b6b-ae15-4ea0d330dcc5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"9ac14cf0-9f2d-49ba-a5f7-6e127a28c92c","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b76f695-2267-4906-8dfb-4bb539ee01cd","type":"BasicTicker"}},"id":"68c4f7a7-7355-4e89-95b8-9d5ff9ba7e65","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2577b05d-d14e-476e-927d-3e250acf87b7","type":"BoxAnnot ...

# %%
def overlay(xydata1, xydata2, charttitle):
    
    output_notebook()  
    x1 = xydata1[:,1]
    y1 = xydata1[:,2]
    x2 = xydata2[:,1]
    y2= xydata2[:,2]
    p = figure(title=charttitle, width = 300, height = 300, x_axis_label='x', y_axis_label='y')
    p.line(x1, y1, line_width=2, color='navy')
    p.line(x2, y2, line_width=2, color='firebrick')
    show(p)

# %%
overlay(PEG_PLGA15k_2CHA_R2_P26, PLGA_15k_2CHA_R2_P37, 'PEG/No PEG')
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3ebb8391-fec6-4a4f-8e2a-729e86b7f066">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="8c114bea-22a1-4be7-8574-893d3401857d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c114bea-22a1-4be7-8574-893d3401857d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c114bea-22a1-4be7-8574-893d3401857d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b41e4db-5990-49aa-80f5-10d16d047a5b":{"roots":{"references":[{"attributes":{},"id":"072be169-274f-4cff-9862-16ab81e13b41","type":"BasicTicker"},{"attributes":{},"id":"35b9f6b1-e4c4-4e0a-a73c-a02d9312feb0","type":"BasicTicker"},{"attributes":{"overlay":{"id":"643800fe-5dfc-4e5e-a302-be63f4e9c6f5","type":"BoxAnnotation"},"plot":{"id":"ff884326-abc8-4735-a0fa-e5b028d34a2f","subtype":"Figure","type":"Plot"}},"id":"e7f79390-1514-4e71-ad92-477a82740bd5","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"dccf8db9-37e2-4569-b6ef-da8a3ca971bd","type":"ColumnDataSource"},"glyph":{"id":"5bbcf9e7-310b-4832-a51d-a49d3aa3e63a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9ba5c53f-14f0-480e-a55c-d66a21564e17","type":"Line"},"selection_glyph":null},"id":"d4c81605-a744-484a-a4e0-8adf48e41126","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ff884326-abc8-4735-a0fa-e5b028d34a2f","subtype":"Figure","type":"Plot"}},"id":"ed697812-9649-4741-8b74-2754ad3547e5","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"3f56b31d-552f-4d18-b149-1898c3f4ad4e","subtype":"Figure","type":"Plot"}},"id":"d5e10c11-711e-471d-aff6-4fc07f66ca98","type":"PreviewSaveTool"},{"attributes":{},"id":"6f5ed664-1bbc-4ca4-a002-b90e94671d46","type":"BasicTicker"},{"attributes":{},"id":"186eac10-3703-4fd7-9326-75cfc4b2be66","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7685706f-812d-4dc8-84fa-489586605e15","type":"Line"},{"attributes":{"plot":{"id":"fbbd7ca5-3f2e-4e53-ac5c-5cfbfdc66f10","subtype":"Figure","type":"Plot"}},"id":"a4429e70-2141-4db2-9169-0393b1770062","type":"HelpTool"},{"attributes":{},"id":"30d01315-2016-49db-bea9-d69a9e313bc0","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fa680de-8a13-44ce-9d4c-3aedd1b77bcf","type":"Line"},{"attributes":{"plot":{"id":"88a39c94-6b78-482c-8d58-08945590cec2","subtype":"Figure","type":"Plot"}},"id":"503cd1dd-d4f9-4b9f-b749-9e993db31783","type":"ResetTool"},{"attributes":{},"id":"5c7025ec-1129-4484-b8d7-8b842ee8cb84","type":"BasicTickFormatter"},{"attributes":{},"id":"1c1ca632-ba3a-49d9-9ceb-26d3cb97b619","type":"ToolEvents"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"04022468-627b-45e1-a4d0-52bb81395b7e","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7f5c2d1c-7968-48ca-9733-897176408ac0","type":"BoxAnnotation"},{"attributes":{},"id":"1fcbf84d-73ab-4c47-8f51-b9910624ab80","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca385ffd-1b73-4b6b-ae15-4ea0d330dcc5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"877039fd-8535-4007-aa93-53a1457eb133","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb92121e-714c-4319-b337-27b4a90b1c56","type":"BasicTicker"}},"id":"3b52f3cd-87ae-4c38-bc25-6103112d2d67","type":"Grid"},{"attributes":{"plot":{"id":"9ac14cf0-9f2d-49ba-a5f7-6e127a28c92c","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b76f695-2267-4906-8dfb-4bb539ee01cd","type":"BasicTicker"}},"id":"68c4f7a7-7355-4e89-95b8-9d5ff9ba7e65","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay" ...

# %%
# You must first run "bokeh serve" to view this example

from numpy import pi, cos, sin, linspace, roll

from bokeh.client import push_session
from bokeh.io import curdoc
from bokeh.plotting import figure

M = 5
N = M*10 + 1
r_base = 8
theta = linspace(0, 2*pi, N)
r_x = linspace(0, 6*pi, N-1)
rmin = r_base - cos(r_x) - 1
rmax = r_base + sin(r_x) + 1

colors = ["FFFFCC", "#C7E9B4", "#7FCDBB", "#41B6C4", "#2C7FB8", "#253494", "#2C7FB8", "#41B6C4", "#7FCDBB", "#C7E9B4"] * M

# figure() function auto-adds the figure to curdoc()
p = figure(x_range=(-11, 11), y_range=(-11, 11))
r = p.annular_wedge(0, 0, rmin, rmax, theta[:-1], theta[1:],
                    fill_color=colors, line_color="white")

# open a session to keep our local document in sync with server
session = push_session(curdoc())

ds = r.data_source

def update():
    rmin = roll(ds.data["inner_radius"], 1)
    rmax = roll(ds.data["outer_radius"], -1)
    ds.data.update(inner_radius=rmin, outer_radius=rmax)

curdoc().add_periodic_callback(update, 30)

session.show() # open the document in a browser

session.loop_until_closed() # run forever

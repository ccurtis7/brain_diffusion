# %%
import numpy as np
from bokeh.plotting import figure, show, gridplot, vplot, hplot, curdoc
from bokeh.io import output_notebook
from trajectory_visualization import plot_trajectory, sidebyside, shift_trajectory, overlay
from bokeh.client import push_session

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f2e2ed22-d5b6-44f7-8acf-b8ff84979c09">Loading BokehJS ...</span>
#     </div>

# %%
trajectory = np.genfromtxt('../sample_data/Sample_Trajectory_Data1.csv',
            delimiter =",")
trajectory=np.delete(trajectory, 0,0)

# %%
time = trajectory[:,0]
PLGA_4A_UP_R1_P25 = trajectory[:,1:4]
PLGA_4A_P80_R1_P22 = trajectory[:,4:7]
PLGA_15k_UP_R3_P5 = trajectory[:,7:10]
PLGA_15k_P80_R3_P36 = trajectory[:,10:13]
PLGA_4A_F68_R3_P15 = trajectory[:,13:16]
PLGA_15k_F68_R3_P10 = trajectory[:,16:19]
PLGA4A_5CHA_R3_P124 = trajectory[:,19:22]
PLGA_15k_5CHA_R3_P50 = trajectory[:,22:25]
PLGA_15k_2CHA_R2_P44 = trajectory[:,25:28]
PLGA15k_05CHA_R3_P22 = trajectory[:,28:31]
PEG_PLGA15k_P80_R3_P127 = trajectory[:,31:34]
PEG_PLGA4A_F68_R3_P111 = trajectory[:,34:37]
PEG_PLGA4A_P80_R1_P84 = trajectory[:,37:40]
PEG_PLGA4A_UP_R1_P53 = trajectory[:,40:43]
PEG_PLGA15k_2CHA_R2_P26 = trajectory[:,43:46]
PEG_PLGA15k_5CHA_R2_P52 = trajectory[:,46:49]
PEG_PLGA15k_UP_R3_P61 = trajectory[:,49:52]
PEG_PLGA58k_5CHA_R2_P15 = trajectory[:,52:55]
PEG_PLGA15k_F68_R2_P81 = trajectory[:,55:58]
PLGA_15k_2CHA_R2_P37 = trajectory[:,58:61]
PLGA_15k_PEG_2CHA_R2_P81 = trajectory[:,61:64]
PLGA_15k_05CHA_R1_P45 = trajectory[:,64:67]
PLGA_15k_PEG_05CHA_R3_P61 = trajectory[:,67:70]

# %%
shift_trajectory(PLGA_4A_UP_R1_P25)
shift_trajectory(PEG_PLGA4A_UP_R1_P53)

shift_trajectory(PLGA_4A_P80_R1_P22)
shift_trajectory(PEG_PLGA4A_P80_R1_P84)

shift_trajectory(PLGA_15k_UP_R3_P5)
shift_trajectory(PEG_PLGA15k_UP_R3_P61)

shift_trajectory(PLGA_15k_P80_R3_P36)
shift_trajectory(PEG_PLGA15k_P80_R3_P127)

shift_trajectory(PLGA_4A_F68_R3_P15)
shift_trajectory(PEG_PLGA4A_F68_R3_P111)

shift_trajectory(PLGA_15k_F68_R3_P10)
shift_trajectory(PEG_PLGA15k_F68_R2_P81)

shift_trajectory(PLGA4A_5CHA_R3_P124)
shift_trajectory(PEG_PLGA58k_5CHA_R2_P15)

shift_trajectory(PLGA_15k_5CHA_R3_P50)
shift_trajectory(PEG_PLGA15k_5CHA_R2_P52)
shift_trajectory(PLGA_15k_2CHA_R2_P37)
shift_trajectory(PLGA_15k_PEG_2CHA_R2_P81)

shift_trajectory(PEG_PLGA15k_2CHA_R2_P26)
shift_trajectory(PLGA_15k_2CHA_R2_P44)

shift_trajectory(PLGA15k_05CHA_R3_P22)
shift_trajectory(PLGA_15k_05CHA_R1_P45)
shift_trajectory(PLGA_15k_PEG_05CHA_R3_P61)
# Out:
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
# Trajectory successfully shifted.
f-4802-881c-48a249f4da58","subtype":"Figure","type":"Plot"},"ticker":{"id":"382057e3-5c3a-49fa-9c3b-0e9572cee401","type":"BasicTicker"}},"id":"e1ef2724-9a04-47f3-bcea-3da44513cb62","type":"Grid"},{"attributes":{"callback":null},"id":"a3dfea14-e2a0-464c-8964-dcadb7ed71d1","type":"DataRange1d"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a0dd3ac1-157e-436b-ae4e-3eda5386e4c4","type":"Line"},{"attributes":{},"id":"2568e356-127d-49fb-969c-07ff1625183d","type":"BasicTicker"},{"attributes":{"plot":{"id":"033ccb77-a1f6-4ef2-8f16-f1870cff5019","subtype":"Figure","type":"Plot"},"ticker":{"id":"45b3763e-967e-4ef2-92a0-f2b7b2713aca","type":"BasicTicker"}},"id":"dc759bee-440e-432c-ad7b-9b460112e08f","type":"Grid"},{"attributes":{"plot":{"id":"ebe18036-6444-49a9-b86e-3ed96346fc74","subtype":"Figure","type":"Plot"}},"id":"6705b017-a071-4477-b5cc-78e92a8b06b6","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"793380a7-ec7f-4802-881c-48a249f4da58","subtype":"Figure","type":"Plot"}},"id":"0ac19f85-4051-4fa9-8d7a-4ceef4f36816","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"793380a7-ec7f-4802-881c-48a249f4da58","subtype":"Figure","type":"Plot"}},"id":"9a162d57-5eed-42fd-b17f-15bb5bb92491","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"033ccb77-a1f6-4ef2-8f16-f1870cff5019","subtype":"Figure","type":"Plot"}},"id":"be032c02-9798-4f69-9cbe-2d527a3f3af5","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"793380a7-ec7f-4802-881c-48a249f4da58","subtype":"Figure","type":"Plot"}},"id":"2d50e373-3204-4664-9b8b-bfe73049648e","type":"HelpTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea12d89f-1cd8-46da-ab4c-024f651813d7","type":"Line"},{"attributes":{},"id":"45b3763e-967e-4ef2-92a0-f2b7b2713aca","type":"BasicTicker"},{"attributes":{"formatter":{"id":"0de3f88d-4479-44dd-9d55-c171dafeb1af","type":"BasicTickFormatter"},"plot":{"id":"033ccb77-a1f6-4ef2-8f16-f1870cff5019","subtype":"Figure","type":"Plot"},"ticker":{"id":"a00b1974-e377-4f55-a706-ecacfe39f92a","type":"BasicTicker"}},"id":"c5b313c6-e390-4944-a2dd-22c0f8974121","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9d6bbbd3-06dc-4bc4-9c25-822200dc39ae","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"ecbd41d6-ab1b-430d-b057-446d89fd6fe1","type":"LinearAxis"}],"left":[{"id":"b159f657-3b4c-4577-b339-d58c2641e5cc","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"ecbd41d6-ab1b-430d-b057-446d89fd6fe1","type":"LinearAxis"},{"id":"342d52d0-b770-41a2-921e-65dd8ce5b330","type":"Grid"},{"id":"b159f657-3b4c-4577-b339-d58c2641e5cc","type":"LinearAxis"},{"id":"00bce28b-03cd-49f5-8be9-abb8fef0c733","type":"Grid"},{"id":"0b29e59b-5cd9-48d9-b59e-85177f32fa15","type":"BoxAnnotation"},{"id":"d80d2e87-47d6-4d23-842a-a8496d1397d8","type":"GlyphRenderer"},{"id":"3a516448-fe0c-4e73-a089-65b3da163f7 ...
# True

# %%
from bokeh.core.state import State as new

# %%
new.reset?

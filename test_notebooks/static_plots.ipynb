# %%
import numpy as np
from bokeh.plotting import figure, show, gridplot
from bokeh.io import output_notebook
from trajectory_visualization import define_xydata, shift_trajectory, download_trajectory_data, plot_trajectory

# %%
trajectory = np.genfromtxt('../sample_data/Sample_Trajectory_Data1.csv',
            delimiter =",")
trajectory=np.delete(trajectory, 0,0)

# %%
time = trajectory[:,0]
PLGA_4A_UP_R1_P25 = trajectory[:,1:4]
PLGA_4A_P80_R1_P22 = trajectory[:,4:7]
PLGA_15k_UP_R3_P5 = trajectory[:,7:10]
PLGA_15k_P80_R3_P36 = trajectory[:,10:13]
PLGA_4A_F68_R3_P15 = trajectory[:,13:16]
PLGA_15k_F68_R3_P10 = trajectory[:,16:19]
PLGA4A_5CHA_R3_P124 = trajectory[:,19:22]
PLGA_15k_5CHA_R3_P50 = trajectory[:,22:25]
PLGA_15k_2CHA_R2_P44 = trajectory[:,25:28]
PLGA15k_05CHA_R3_P22 = trajectory[:,28:31]
PEG_PLGA15k_P80_R3_P127 = trajectory[:,31:34]
PEG_PLGA4A_F68_R3_P111 = trajectory[:,34:37]
PEG_PLGA4A_P80_R1_P84 = trajectory[:,37:40]
PEG_PLGA4A_UP_R1_P53 = trajectory[:,40:43]
PEG_PLGA15k_2CHA_R2_P26 = trajectory[:,43:46]
PEG_PLGA15k_5CHA_R2_P52 = trajectory[:,46:49]
PEG_PLGA15k_UP_R3_P61 = trajectory[:,49:52]
PEG_PLGA58k_5CHA_R2_P15 = trajectory[:,52:55]
PEG_PLGA15k_F68_R2_P81 = trajectory[:,55:58]
PLGA_15k_2CHA_R2_P37 = trajectory[:,58:61]
PLGA_15k_PEG_2CHA_R2_P81 = trajectory[:,61:64]
PLGA_15k_05CHA_R1_P45 = trajectory[:,64:67]
PLGA_15k_PEG_05CHA_R3_P61 = trajectory[:,67:70]

# %%
#output to notebook
output_notebook()

# %%
def shift_trajectory(xydata):
    """
    
    """
    x_mean = (np.min(xydata[:,1]) + np.max(xydata[:,1]))/2
    y_mean = (np.min(xydata[:,2]) + np.max(xydata[:,2]))/2

    xydata[:,1] = xydata[:,1] - x_mean
    xydata[:,2] = xydata[:,2] - y_mean
    
    return xydata

# %%
def plot_trajectory(xydata, charttitle):
    
    x = xydata[:,1]
    y = xydata[:,2]
    p = figure(title=charttitle, title_text_font_size='8pt', 
               width = 300, height = 300, x_axis_label='x', y_axis_label='y')
    p.line(x, y, line_width=2)
    show(p)

# %%
shift_trajectory(PEG_PLGA15k_2CHA_R2_P26)
plot_trajectory(PEG_PLGA15k_2CHA_R2_P26, 'PEG_PLGA15k_2CHA_R2_P26')

# %%
pink = np.chararray((3, 3))
pink[:] = 'a'
np.dtype(pink[0,0])

# %%
length = pink.shape[0]
width = pink.shape[1]
numerical = True

for num in range(0,width):
    
    for yes in range(0,length):

        if np.dtype(pink[yes,num]) == np.dtype('float64'):
            numerical = True
        else:
            numerical = False
            break

# %%
from trajectory_visualization import shift_trajectory

# %%
shift_trajectory(PLGA_15k_F68_R3_P10)

# %%
trajectory = download_trajectory_data('../sample_data/Sample_Trajectory_Data1.csv')
time, Run = define_xydata(trajectory, 2)

# %%
PLGA_4A_UP_R1_P25 = Run['Run1']
PLGA_4A_P80_R1_P22 = Run['Run2']

# %%
shift_trajectory(PLGA_4A_UP_R1_P25)
shift_trajectory(PLGA_4A_P80_R1_P22)
# Out:
# 'Trajectory successfully shifted.'

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64634d22-f421-4aec-b257-bd6da7daba86">Loading BokehJS ...</span>
#     </div>

# %%
plot_trajectory(PLGA_4A_UP_R1_P25, 'PLGA_4A_P80_R1_P22')
# Out:
#     <div class="plotdiv" id="51980e62-e757-4927-823f-0a2f8e8aae74"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51980e62-e757-4927-823f-0a2f8e8aae74");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51980e62-e757-4927-823f-0a2f8e8aae74' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"038d759d-c2d4-4a06-b578-681cfb769763":{"roots":{"references":[{"attributes":{"plot":{"id":"14f4b7d8-d1ee-4dea-bd05-b0ee3e94d8e8","subtype":"Figure","type":"Plot"}},"id":"e1e018ef-6cd2-4ec4-809b-59d83d14458d","type":"ResizeTool"},{"attributes":{"plot":{"id":"e9ca9e9d-461f-4b61-a7bd-e3291fdf3c9e","subtype":"Figure","type":"Plot"}},"id":"77bc94dd-b2e8-425c-9c4b-b777715d5fe2","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"faa9269e-cd0e-4895-b60d-028adde405ea","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d9264829-c2e1-4176-ab35-3b6a72007725","type":"LinearAxis"}],"left":[{"id":"089027d5-4d78-45d2-b801-7b3a5e0145e2","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"d9264829-c2e1-4176-ab35-3b6a72007725","type":"LinearAxis"},{"id":"85efc1ea-8a78-42c4-baa3-e5364f07039a","type":"Grid"},{"id":"089027d5-4d78-45d2-b801-7b3a5e0145e2","type":"LinearAxis"},{"id":"e193272e-5375-4d6c-a885-cf168e5b63e5","type":"Grid"},{"id":"faa9269e-cd0e-4895-b60d-028adde405ea","type":"BoxAnnotation"},{"id":"918b606c-5b18-4a15-a26e-75ee151d951b","type":"GlyphRenderer"}],"title":"PLGA_4A_P80_R1_P22","title_text_font_size":{"value":"8pt"},"tool_events":{"id":"c944e2f2-9d72-4c61-b6ef-c11d866c2ebc","type":"ToolEv
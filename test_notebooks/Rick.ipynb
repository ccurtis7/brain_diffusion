# %%
from functions_rick import interact_plot_deff, working_data

# %%
interact_plot_deff()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="84ffa7b1-c6d7-404f-8030-788d0e8dad78">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="cb538f2d-f9e6-4603-9d32-86b9763dbf46"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cb538f2d-f9e6-4603-9d32-86b9763dbf46");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cb538f2d-f9e6-4603-9d32-86b9763dbf46' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6de97c37-c99c-40df-9beb-75a7eb27b5e6":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1074173-e861-46ed-aa6a-b086ad13fbdf","type":"Rect"},{"attributes":{"callback":null,"column_names":["height","color","fill_alpha","line_alpha","x","y","line_color","width"],"data":{"Particle":["PLGA58k UP"],"chart_index":[{"Particle":"PLGA58k UP"}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[13.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.0011498149999999998],"x":["0.0017499999999999998"],"y":[6.5]}},"id":"dc6ffb03-cd3a-48e9-85f7-432ed27b1ae4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["height","color","fill_alpha","line_alpha","x","y","line_color","width"],"data":{"Particle":["PEG-PLGA15k P80"],"chart_index":[{"Particle":"PEG-PLGA15k P80"}],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[12.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.00017699999999999997],"x":["0.000635"],"y":[6.0]}},"id":"365aad72-7eca-4d20-ba40-fe130111e359","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"19c17322-152e-4f3b-afee-33cc8e1e062d","type":"ColumnDataSource"},"glyph":{"id":"a15f18b7-18c1-4efe-9745-e51bb8fa92ba","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"58775094-3af0-4f1c-a275-9b65c7f061bf","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"be09d123-9e49-4e28-b968-6341c7369496","type":"ColumnDataSource"},"glyph":{"id":"317c1b39-8fcc-4ec1-81a7-1bb6a74ccc63","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"059a0499-f3c7-43ac-875d-8870dea6e695","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b56aeb32-04ce-44c4-8d38-a12ad1b08bbe","type":"ColumnDataSource"},"glyph":{"id":"c51f2d26-e7f4-4621-a71e-3ae1262bca30","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"abab60d0-0323-4833-a582-243cac893352","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"409778ec-abb4-47f9-86b2-e8f357a37a0c","type":"Rect"},{"attributes":{"data_source":{"id":"641be619-85dc-48cc-8d51-259a84a39624","type":"ColumnDataSource"},"glyph":{"id":"3b9c69d7-5a3a-44e9-9abd-6472e9ee3f6b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5aefdc60-8ace-49ba-acd7-ec2423bbc279","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["height","color","fill_alpha","line_alpha","x","y","line_color","width"],"data":{"Particle":["PLGA58k 5CHA"],"chart_index":[{"Particle":"PLGA58k 5CHA"}],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.008026499999999999],"x":["0.02"],"y":[0.0]}},"id":"6b4907be-4ee6-44c9-ad90-7fcd9a043dec","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["height","color","fill_alpha","line_alpha","x","y","line_color","width"],"data":{"Particle":["PLGA15k F68"],"chart_index":[{"Particle":"PLGA15k F68"}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.0008909999999999999],"x":["0.0048000000000000004"],"y":[0.0]}},"id":"1e9abdec-ce59-420c-89c1-351825aafeab","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["height","color","fill_alpha","line_alpha","x","y","line_color","width"],"data":{"Particle":["PEG-PLGA15k 5CHA"],"chart_index":[{"Particle":"PEG-PLGA15k 5CHA"}],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[1.0099999999999998],"x":["7.555"],"y":[ ...

# %%
"""
    zf = zipfile.ZipFile('brain-diffusion_data.zip')
    file_handle1 = zf.open('Effective_Diffusion_1s_Data.csv')
    deff = pd.read_csv(file_handle1)
    deff = deff.set_index('Particle')
    deff = deff.transpose()
    """

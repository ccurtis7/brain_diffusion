# %%
import numpy as np
import pandas as pd
import zipfile

# %%
zf = zipfile.ZipFile('brain-diffusion_data.zip')
file_handle1 = zf.open('Effective_Diffusion_1s_Data.csv')
deff = pd.read_csv(file_handle1)
file_handle2 = zf.open('Particle_Properties_Data.csv')
prop = pd.read_csv(file_handle2)

# %%
def working_data(size_center,size_tick,zp_tick):
    prop['Size_Range'] = 0
    prop['ZP_Range'] = 0
    size_range = set_size_range(size_center,size_tick)
    zp_range = set_zp_range(zp_tick)
    for x in range(0, len(prop)):
        for y in range(0, len(size_range)):
            if prop['Size'][x] >= size_range['Low'][y] and prop['Size'][x] < size_range['High'][y]:
                prop.loc[[x],['Size_Range']] = size_range['Size_Range'][y]
                break
        for z in range(0,len(zp_range)):
            if prop['Zeta_Potential'][x] >= zp_range['Low'][z] and prop['Zeta_Potential'][x] < zp_range['High'][z]:
                prop.loc[[x],['ZP_Range']] = zp_range['ZP_Range'][z]
                break
    deff2 = deff.set_index('Particle')
    prop2 = prop.set_index('Sample')
    data = prop2.join(deff2)
    return data

# %%
def set_size_range(center,tick):
    low = center
    while low > min(prop['Size']):
        low = low-tick
    high = center
    while high < max(prop['Size']):
        high = high+tick
    rows = (high-low)/tick
    rows = int(rows)
    sizes_array = np.zeros((rows,4))
    sizes = pd.DataFrame(sizes_array[1:,1:])
    sizes.columns = ['Low','High','Size_Range']
    for x in range(0,rows-1):
        sizes.loc[[x],['Low']] = low+tick*x
        sizes.loc[[x],['High']] = low+tick*(x+1)
        sizes.loc[[x],['Size_Range']] = '%i to %i' % (sizes['Low'][x], sizes['High'][x])
    return sizes

# %%
def set_zp_range(tick):
    low = 0
    while low > min(prop['Zeta_Potential']):
        low = low-tick
    rows = (0-low)/tick
    rows = int(rows)
    zp_array = np.zeros((rows+1,4))
    zp = pd.DataFrame(zp_array[1:,1:])
    zp.columns = ['Low','High','ZP_Range']
    for x in range(0,rows):
        zp.loc[[x],['Low']] = low+tick*x
        zp.loc[[x],['High']] = low+tick*(x+1)
        zp.loc[[x],['ZP_Range']] = '%i to %i' % (zp['Low'][x], zp['High'][x])
    return zp

# %%
working_data(100,10,5)
# Out:
#                    Sample_ID Particle_Type Surfactant  PEG        Size  \
# PEG-PLGA15k 0.5CHA   1-92-16           15k     0.5CHA  Yes   69.100000
# PEG-PLGA15k 0.5CHA   1-92-16           15k     0.5CHA  Yes   69.100000
# PEG-PLGA15k 0.5CHA   1-92-16           15k     0.5CHA  Yes   69.100000
# PEG-PLGA15k 2CHA     1-92-14           15k       2CHA  Yes   66.033333
# PEG-PLGA15k 2CHA     1-92-14           15k       2CHA  Yes   66.033333
# PEG-PLGA15k 2CHA     1-92-14           15k       2CHA  Yes   66.033333
# PEG-PLGA15k 5CHA     1-92-12           15k       5CHA  Yes   59.300000
# PEG-PLGA15k 5CHA     1-92-12           15k       5CHA  Yes   59.300000
# PEG-PLGA15k 5CHA     1-92-12           15k       5CHA  Yes   59.300000
# PLGA15k 0.5CHA       3.900000      -48.100000  3.500000  0.090000           4
# PLGA15k 0.5CHA       3.900000      -48.100000  3.500000  0.090000           4
# PLGA15k 2CHA         0.800000      -43.400000  3.200000  0.060000           4
# PLGA15k 2CHA         0.800000      -43.400000  3.200000  0.060000           4
# PLGA15k 2CHA         0.800000      -43.400000  3.200000  0.060000           4
# PLGA15k 5CHA         1.400000      -42.100000  2.200000  0.090000           2
# PLGA15k 5CHA         1.400000      -42.100000  2.200000  0.090000           2
# PLGA15k 5CHA         1.400000      -42.100000  2.200000  0.090000           2
# PLGA15k F68          1.500000      -21.800000  1.600000  0.070000           4
# PLGA15k F68          1.500000      -21.800000  1.600000  0.070000           4
# PLGA15k F68          1.500000      -21.800000  1.600000  0.070000           4
# PLGA15k P80          3.000000      -22.400000  1.000000  0.080000           4
# PLGA15k P80          3.000000      -22.400000  1.000000  0.080000           4
# PLGA15k P80          3.000000      -22.400000  1.000000  0.080000           4
# PLGA15k UP           3.300000      -33.300000  3.400000  0.090000           4
# PLGA15k UP           3.300000      -33.300000  3.400000  0.090000           4
# PLGA15k UP           3.300000      -33.300000  3.400000  0.090000           4
# PLGA58k 5CHA         1.400000      -38.900000  6.700000  0.100000           3
# PLGA58k 5CHA         1.400000      -38.900000  6.700000  0.100000           3
# PLGA58k 5CHA         1.400000      -38.900000  6.700000  0.100000           3
# PLGA58k F68         89.600000      -21.100000  3.000000  0.100000           4
# PLGA58k F68         89.600000      -21.100000  3.000000  0.100000           4
# PLGA58k F68         89.600000      -21.100000  3.000000  0.100000           4
# PLGA58k P80          4.900000      -20.400000  1.700000  0.070000           3
# PLGA58k P80          4.900000      -20.400000  1.700000  0.070000           3
# PLGA58k P80          4.900000      -20.400000  1.700000  0.070000           3
# PLGA58k UP           3.800000      -26.400000  1.700000  0.130000           4
# PLGA58k UP           3.800000      -26.400000  1.700000  0.130000           4
# PLGA58k UP           3.800000      -26.400000  1.700000  0.130000           4
#
#                       ...          193       194       195       196  \
# PEG-PLGA15k 0.5CHA    ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 0.5CHA    ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 0.5CHA    ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 2CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 2CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 2CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 5CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 5CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k 5CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k UP        ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k UP        ...          NaN       NaN       NaN       NaN
# PEG-PLGA15k UP        ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k 5CHA      ...     0.000149  0.004277  0.018563  0.000349
# PEG-PLGA45k 5CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k 5CHA      ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k F68       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k P80       ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k UP        ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k UP        ...          NaN       NaN       NaN       NaN
# PEG-PLGA45k UP        ...          NaN       NaN       NaN       NaN
# PLGA15k 0.5CHA        ...          NaN       NaN       NaN       NaN
# PLGA15k 0.5CHA        ...          NaN       NaN       NaN       NaN
# PLGA15k 0.5CHA        ...          NaN       NaN       NaN       NaN
# PLGA15k 2CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k 2CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k 2CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA15k F68           ...          NaN       NaN       NaN       NaN
# PLGA15k F68           ...          NaN       NaN       NaN       NaN
# PLGA15k F68           ...          NaN       NaN       NaN       NaN
# PLGA15k P80           ...          NaN       NaN       NaN       NaN
# PLGA15k P80           ...          NaN       NaN       NaN       NaN
# PLGA15k P80           ...          NaN       NaN       NaN       NaN
# PLGA15k UP            ...          NaN       NaN       NaN       NaN
# PLGA15k UP            ...          NaN       NaN       NaN       NaN
# PLGA15k UP            ...          NaN       NaN       NaN       NaN
# PLGA58k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA58k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA58k 5CHA          ...          NaN       NaN       NaN       NaN
# PLGA58k F68           ...          NaN       NaN       NaN       NaN
# PLGA58k F68           ...          NaN       NaN       NaN       NaN
# PLGA58k F68           ...          NaN       NaN       NaN       NaN
# PLGA58k P80           ...          NaN       NaN       NaN       NaN
# PLGA58k P80           ...          NaN       NaN       NaN       NaN
# PLGA58k P80           ...          NaN       NaN       NaN       NaN
# PLGA58k UP            ...          NaN       NaN       NaN       NaN
# PLGA58k UP            ...          NaN       NaN       NaN       NaN
# PLGA58k UP            ...          NaN       NaN       NaN       NaN
#
#                          197       198       199       200      201       202
# PEG-PLGA15k 0.5CHA       NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 0.5CHA       NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 0.5CHA       NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 2CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 2CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 2CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 5CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 5CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k 5CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA15k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k 5CHA    0.001399  0.001302  1.305068  0.152999  4.26173  9.697275
# PEG-PLGA45k 5CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k 5CHA         NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k F68          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k P80          NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PEG-PLGA45k UP           NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 0.5CHA           NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 0.5CHA           NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 0.5CHA           NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 2CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 2CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 2CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k UP               NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k UP               NaN       NaN       NaN       NaN      NaN       NaN
# PLGA15k UP               NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k 5CHA             NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k F68              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k P80              NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k UP               NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k UP               NaN       NaN       NaN       NaN      NaN       NaN
# PLGA58k UP               NaN       NaN       NaN       NaN      NaN       NaN
#
# [60 rows x 224 columns]

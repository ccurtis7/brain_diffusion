# %%
from functions_rick import working_data, plot_Deff

# %%
data = working_data(100,10,5)
data.head()
# Out:
#      Particle      Deff Particle_Type Surfactant PEG Size_Range    ZP_Range
# 0  PLGA58k UP  0.000079           58k         UP  No   80 to 90  -30 to -25
# 1  PLGA58k UP  0.000040           58k         UP  No   80 to 90  -30 to -25
# 2  PLGA58k UP  0.000170           58k         UP  No   80 to 90  -30 to -25
# 3  PLGA58k UP  0.000248           58k         UP  No   80 to 90  -30 to -25
# 4  PLGA58k UP  0.000315           58k         UP  No   80 to 90  -30 to -25

# %%
plot_Deff(100,10,5,10)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="84276d1d-7e74-4fcc-96bd-30affc6047b4">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="1a9e619b-a50f-4b8f-84dd-de62d1844dd2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a9e619b-a50f-4b8f-84dd-de62d1844dd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a9e619b-a50f-4b8f-84dd-de62d1844dd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d4bb6027-80f2-4ff7-831a-6173c048af23":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6b9035e-222e-4155-aa43-1925119f6772","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","height","line_color","color","fill_alpha","x","line_alpha","width"],"data":{"Particle":["PEG-PLGA15k 2CHA"],"chart_index":[{"Particle":"PEG-PLGA15k 2CHA"}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.4020000000000001],"x":["3.0"],"y":[0.0]}},"id":"6c0ab4a7-3339-44eb-a3f4-79ba7b1abe3d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb334779-eb96-4212-ab73-220e676c0707","type":"Rect"},{"attributes":{"data_source":{"id":"8a84aa16-932d-4e51-a967-4256b6e67872","type":"ColumnDataSource"},"glyph":{"id":"99060d26-186f-447b-b6e7-c6fe05b49ca6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0f8e68d5-d31d-4141-ad7f-90e461032ea6","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c4274d39-ae5a-4e76-9497-c4f1545bdb3a","type":"ColumnDataSource"},"glyph":{"id":"dc26dc19-1394-468c-a474-13f7e1a2ccf2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"41c24793-47e0-4726-9d59-6a29e601d144","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","height","line_color","color","fill_alpha","x","line_alpha","width"],"data":{"Particle":["PEG-PLGA45k P80"],"chart_index":[{"Particle":"PEG-PLGA45k P80"}],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.02613],"x":["0.039"],"y":[0.0]}},"id":"5618ac81-f698-4366-97be-6951e4cc52dc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"adb4f658-20f4-47ca-a53f-ce9b55eee1b7","type":"ColumnDataSource"},"glyph":{"id":"72659aba-1549-41de-b95d-999f0626d573","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"694be770-2ac9-4b19-9e4f-17caacea2d4f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","height","line_color","color","fill_alpha","x","line_alpha","width"],"data":{"Particle":["PEG-PLGA15k 5CHA"],"chart_index":[{"Particle":"PEG-PLGA15k 5CHA"}],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[1.0099999999999998],"x":["4.535"],"y":[0.0]}},"id":"6c7cb525-a283-45f7-a37b-490827d15145","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c80aa1a8-0f9f-4d6f-892d-332983df9976","type":"ColumnDataSource"},"glyph":{"id":"a84be740-7ff5-4888-be45-ef0fc66a3851","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"26b3ee41-60b5-428d-8568-ff05f62bda35","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5514c6cd-eb57-4f69-a27a-b93e2736f7a3","type":"Rect"},{"attributes":{"data_source":{"id":"b49e1e07-9261-430a-8cb0-83ffb3092b06","type":"ColumnDataSource"},"glyph":{"id":"80ccd28d-cb2b-403f-8d0d-d1d6a47eda86","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bac17bc9-573e-4ce2-8319-a5bb6239a10c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7b4a14fc-64a0-4020-b885-5d5ebb9b6a84","type":"ColumnDataSource"},"glyph":{"id":"3eb095bb-69ae-4ade-a105-00a1a6f83555","type":"Rect"},"hover_glyph":null,"nonselection_glyph": ...

# %% [markdown]
# do interactive widgets
# put in unit tests

# %%
from ipywidgets import interact, interactive
from IPython.display import clear_output, display, HTML
